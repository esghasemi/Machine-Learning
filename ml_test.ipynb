# %% [markdown]
# <a href="https://colab.research.google.com/github/esghasemi/Machine-Learning/blob/main/ml_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World !!')
# Out:
# Hello World !!
